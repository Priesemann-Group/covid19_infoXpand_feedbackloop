# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import time

# %%
import sys
sys.path.append("../code")
import model
import plotting
import parameters
import cosmodata

# %%
#CosmoStringency, CosmoICU, CosmovsICU, KernelR, KernelV, Romania, Willingness, Vaccination

motivation = {
    'ax1': 'CosmoICU',
    'ax2': 'CosmovsICU',
    'ax3': 'ContactFeedback',
    'ax4': 'Romania',
    'ax5': 'Willingness',
    'ax6': 'Vaccination',

    'cICU': '#00468BFF',
    'cStringency': 'orange',
    'cCosmodata': 'red',
    'cVaccines': '#0099B4FF',
    'cFit': 'black',
    'cVac1': '#10750FFF',
    'cVac2': '#70AC6FFF',
}

# %%
plotting.motivation(motivation, path='./figures/fig_motivation.pdf', arial=True)
# Out:
# Parameters: [4.32527984 0.0189039 ]
# Softplus Correlation: 0.6002728472017711
